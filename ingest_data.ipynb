# %%
import os 
import json
from pymongo import MongoClient
from pymongo import MongoClient
import pandas as pd
MONGO_CONNECTION_STRING = ""

# %%
def json_to_mongo(json_file, collection_name, database_name):
    # Load JSON data
    with open(json_file, "r") as f:
        data = json.load(f)

    # Add 'data_to_embed' field
    for item in data:
        # Can this be done at the time of embedding? Projection did not work in contoso-booking notebook
        item['data_to_embed'] = f"{item.get('name', '')} {item.get('description', '')} {item.get('neighborhood_overview', '')}" 

    #Insert JSON data into MongoDB collection
    client = MongoClient(MONGO_CONNECTION_STRING)
    db = client[database_name]
    collection = db[collection_name]
    collection.insert_many(data)
    client.close()
    print(f"Inserted {len(data)} documents into the '{collection_name}' collection in MongoDB.")

json_to_mongo("data/datasets without embeddings/small_for_testing.json", "listings", "contoso_bookings_concat" )
# Out:
# Inserted 1434 documents into the 'listings' collection in MongoDB.

# %%
client = MongoClient(MONGO_CONNECTION_STRING)
db = client["contoso_bookings_concat"]
collection = db["listings"]
db.command({
  'createIndexes': 'listings',
  'indexes': [
    {
      'name': 'listingIndex',
      'key': {
        "embeddings": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-diskann',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})
# Out:
# {'raw': {'defaultShard': {'numIndexesBefore': 1,
#    'numIndexesAfter': 2,
#    'createdCollectionAutomatically': False,
#    'ok': 1}},
#  'ok': 1}

# %%
import time
from pymongo import UpdateOne
batch_size = 15
total_updated = 0
iteration = 0

while True:
    iteration += 1

    # Find records to update
    records_to_update = collection.find({
    '$and': [
        {'embeddings': {'$exists': False}},
        {'data_to_embed': {'$exists': True}}
    ]
    }).limit(batch_size)

    records_to_update = list(records_to_update)
    print(records_to_update)

    if not records_to_update:
        print(f"All rows have been updated. Total updated rows: {total_updated}")
        break

    total_updated += len(records_to_update)

    print(f"Iteration: {iteration}, has handled {total_updated} rows")

    # Prepare bulk operations
    bulk_ops = [
        UpdateOne({'_id': record['_id']},
                {'$generateEmbeddings': {'data_to_embed': 'embeddings'}})
        for record in records_to_update
    ]

    if bulk_ops:
        result = collection.bulk_write(bulk_ops)
        print(f"Bulk write result: {result.bulk_api_result}")

    time.sleep(0.5)  # Sleep for 500 ms
# Out:
# [{'_id': ObjectId('67288be6f310036be2627a5e'), 'id': '360', 'listing_url': 'https://www.airbnb.com/rooms/360', 'source': 'city scrape', 'name': 'Sit in the Peaceful Garden of the Chickadee Cottage in LoHi', 'description': "Enjoy the famous Colorado weather and unplug in indoor & outdoor living. <br />Our charming cottage has a serene ambiance throughout every area. <br />Spend a sunny afternoon out on the hammock or enjoy the garden parlor sofa relax, read, or play a game, sink into the shared hot tub, practice yoga on the deck.<br />We are located next to downtown and in the neighborhood of lower highlands, <br />Short walks to superb coffee shops, restaurants, microbrews, distilleries, dispensaries & downtown. We are 420 outdoors only. LGBT Friendly, allergy-free, fragrance-free & pet-free. Ozone sterilized.<br /><br />Chickadee Cottage is the largest of our guest cottages.<br /><br />LOCATION: <br />The cottage is located in the center of Lower Highlands (LOHI) next to the Navajo Street Arts District along with the Bug Theater. Check out the Bugs listing to see what's going on - plays/film/comedy nights. No need to cab it because we are in the midst of it all.<br /><br />COTTAGE DESCRIPTION: <br /><br", 'neighborhood_overview': 'The cottage is located in the center of Lower Highlands (LOHI) next to the Navajo Street Arts District. Catch a show at the iconic Bug Theater. Wandering the neighborhood to discover breweries, distilleries and bars for local drinks, tuck into a family owned taqueria or explore more formal dinning experience. We are a vibrant neighborhood in Denver where you can see and do but just a quick walk thru the park to downtown, or a mile drive to RiNo. We are just 2.5 mile walk or dirve to Meow Wolf.', 'latitude': '39.766414642333984', 'longitude': '-105.0020980834961', 'price': '$161.00', 'amenities': '["Hangers", "Essentials", "Dedicated workspace", "Microwave", "Shampoo", "Hair dryer", "Oven", "Stainless steel gas stove", "Dishes and silverware", "Single level home", "Shared backyard \\u2013 Fully fenced", "Self check-in", "Smoke alarm", "Board games", "Hammock", "First aid kit", "Body soap", "Carbon monoxide alarm", "Fire extinguisher", "Luggage dropoff allowed", "Outdoor dining area", "Shared patio or balcony", "Heating", "Kitchen", "Fire pit", "Refrigerator", "Cooking basics", "Shared hot tub", "Extra pillows and blankets", "TV with Hulu, HBO Max, Netflix, Roku", "BBQ grill", "Free washer \\u2013 In unit", "Courtyard view", "Central air conditioning", "Ceiling fan", "Free street parking", "Long term stays allowed", "Room-darkening shades", "Coffee maker: espresso machine", "Outdoor furniture", "Iron", "Hot water kettle", "Keypad", "Wifi \\u2013 36 Mbps", "Bed linens", "Exterior security cameras on property", "Free dryer \\u2013 In unit", "Bathtub"]', 'beds': '2', 'bedrooms': '2', 'bathrooms': '1.0', 'bathrooms_text': '1 bath', 'property_type': 'Entire guesthouse', 'room_type': 'Entire home/apt', 'host_about': 'We are artists and tinkerers.\n \nWe enjoy many activities here in Denver -  cooking, growing fruits and vegetables are some that we get to do here at the cottages along with mixed media projects and furniture building. \n\nWe are always up to some new outdoor project when the Colorado weather permits and hunker down inside by the fire in the winter keeping our hands busy with knitting, card making or some other project we can dream up.   In fact the most recent outdoor project is for an outdoor parlor that will be winter friendly. \n\nGiovanni and I have grown in our collaborations and embrace our age and abilities  for self governance in employment - Giovanni had moved into documentaries and I have been spending more time in the commercial film community. \n\nWe have been in the lower highlands for over a decade now and have marveled in the changing landscape and exciting times for new restaurants, breweries and galleries.  We still love to take advantage of the great walks thru the neighborh ...
# Iteration: 1, has handled 15 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67288be6f310036be2627a6c'), 'id': '504080', 'listing_url': 'https://www.airbnb.com/rooms/504080', 'source': 'city scrape', 'name': 'Creative Haven in Artist’s Abode', 'description': 'This two-bedroom, two-bath house is filled with treasures, trinkets, art, and oddities from around the world. Features a spacious front yard, patio, cozy corners, large kitchen, and unique curios from near and far. Curious adventure seekers and art aficionados will delight at this special space!', 'neighborhood_overview': 'The Clayton neighborhood is a rapidly changing area. A historically Black neighborhood of Denver, in the last decade the neighborhood has been experiencing significant gentrification. Many people in the Clayton area actively participate in neighborhood initiatives to help build relationships and engage in mutual aid efforts with our neighbors. For visitors to the neighborhood, a smile and a kind greeting can go a long way to connecting with folks you might encounter on your walk to the local coffee shop!', 'latitude': '39.76574', 'longitude': '-104.95379', 'price': '$115.00', 'amenities': '["Hangers", "Essentials", "Dishwasher", "Dedicated workspace", "Toaster", "Microwave", "Shampoo", "Hair dryer", "Oven", "Baking sheet", "Clothing storage: closet and dresser", "Dishes and silverware", "Single level home", "Self check-in", "Smoke alarm", "Wifi \\u2013 16 Mbps", "Dining table", "Portable fans", "Freezer", "First aid kit", "Private patio or balcony", "Body soap", "Carbon monoxide alarm", "Fire extinguisher", "Wine glasses", "Luggage dropoff allowed", "Washer", "Outdoor dining area", "Cleaning products", "Record player", "Lockbox", "Heating", "Kitchen", "Refrigerator", "Cooking basics", "Extra pillows and blankets", "Backyard", "Sound system", "Hot water", "Coffee maker", "Dryer", "Free street parking", "Ceiling fan", "Long term stays allowed", "Bathtub", "Conditioner", "Outdoor furniture", "Free parking on premises", "Iron", "Hot water kettle", "Stove", "Bed linens", "TV"]', 'beds': '2', 'bedrooms': '2', 'bathrooms': '2.0', 'bathrooms_text': '2 baths', 'property_type': 'Entire home', 'room_type': 'Entire home/apt', 'host_about': 'Artist and entrepreneur. I’m a writer, performer, traveler, and former nonprofit director working in the disability field. I’m curious about rocks, dinosaurs and mass extinction events, the evolution of languages, cultural mashups, emergency management, outsider art, puns, strange foods, and much more!', 'data_to_embed': 'Creative Haven in Artist’s Abode This two-bedroom, two-bath house is filled with treasures, trinkets, art, and oddities from around the world. Features a spacious front yard, patio, cozy corners, large kitchen, and unique curios from near and far. Curious adventure seekers and art aficionados will delight at this special space! The Clayton neighborhood is a rapidly changing area. A historically Black neighborhood of Denver, in the last decade the neighborhood has been experiencing significant gentrification. Many people in the Clayton area actively participate in neighborhood initiatives to help build relationships and engage in mutual aid efforts with our neighbors. For visitors to the neighborhood, a smile and a kind greeting can go a long way to connecting with folks you might encounter on your walk to the local coffee shop!'}, {'_id': ObjectId('67288be6f310036be2627a6d'), 'id': '548897', 'listing_url': 'https://www.airbnb.com/rooms/548897', 'source': 'city scrape', 'name': 'TreeHouseSuite, in Healing Center ~30 DAYS OR MORE', 'description': 'A lovely get-away with a private garden entrance & bathroom, glowing eastern light and a writing desk. Enjoy the peaceful vibration resonating from in-house healers. <br /><br />Carla Madison Denver Recreational Center across the street. Great walkability to restaurants, parks and movie theater. Easy access to B-cycle rentals, walking or bus - just a block away on Colfax!', 'neighborhood_overview': "The City Park neighborhood  ...
# Iteration: 2, has handled 30 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67288be6f310036be2627a7b'), 'id': '958612', 'listing_url': 'https://www.airbnb.com/rooms/958612', 'source': 'city scrape', 'name': 'DENVER SUITE MOUNTAIN VIEW GREAT LOCATION', 'description': 'DENVER SUITE WITH A MOUNTAIN VIEW: live in the very heart of downtown and enjoy a beautiful and peaceful mountain view!  Fully furnished 2 bedroom / 2 bathroom suite with an open plan living/dining room furnished with contemporary leather furniture and original artwork.  Perfect for an extended stay for a small family or a business traveler.', 'neighborhood_overview': "IDEAL LOCATION: Walk out of this suite, take the elevator down, step through the lobby and you are THERE, truly in DOWNTOWN! The Performing Arts Center is just a half-block away. The Convention Center is just two blocks away as is historic Larimer Square, with all of its restaurants, cafes, bars, deli/coffee shops. On the corner is Sam's Diner, open early and late which offers up a true slice of city life and great people watching.<br /><br />Everything else is an easy walk, including the Pepsi Center, Platte Valley, Union Station, the Denver Art Museum, the Clyfford Still Museum, Museum of Contemporary Art, Coors Field baseball stadium. Confluence Park (REI, river walk and kayaking) Elitch Gardens Theme Park  as well as Tattered Cover bookstore and many other sporting and cultural attractions.", 'latitude': '39.74646', 'longitude': '-104.99688', 'price': '$105.00', 'amenities': '["Coffee maker: drip coffee maker", "Hangers", "Essentials", "Dishwasher", "Books and reading material", "Dedicated workspace", "Toaster", "Microwave", "Shampoo", "Hair dryer", "Paid dryer \\u2013 In building", "Paid parking on premises", "Oven", "Exercise equipment: free weights, stationary bike, treadmill, workout bench", "Baking sheet", "Dishes and silverware", "Sun loungers", "Single level home", "Pool table", "City skyline view", "Ethernet connection", "Shared BBQ grill: gas", "Building staff", "Self check-in", "Smoke alarm", "Dining table", "Blender", "Portable fans", "Freezer", "Mountain view", "First aid kit", "Private patio or balcony", "Body soap", "Paid washer \\u2013 In building", "Carbon monoxide alarm", "Fire extinguisher", "Wine glasses", "Elevator", "Luggage dropoff allowed", "Pets allowed", "Outdoor dining area", "Cleaning products", "Fast wifi \\u2013 102 Mbps", "Kitchen", "Cleaning available during stay", "Refrigerator", "Shared gym in building", "Cooking basics", "Extra pillows and blankets", "45 inch HDTV", "Kenmore electric stove", "Hot water", "Clothing storage: closet", "Laundromat nearby", "Central air conditioning", "Long term stays allowed", "Paid parking garage off premises", "Outdoor furniture", "Central heating", "Iron", "Hot water kettle", "Indoor fireplace: electric", "Bed linens", "Exterior security cameras on property", "Shared outdoor pool - available seasonally, heated", "Bathtub"]', 'beds': '2', 'bedrooms': '2', 'bathrooms': '2.0', 'bathrooms_text': '2 baths', 'property_type': 'Entire condo', 'room_type': 'Entire home/apt', 'host_about': 'I enjoy the hospitality. \nI love to share my passion for local history, attractions, outdoor activities, and beautiful scenery with our guests. I like helping our people to plan their vacation. We try to provide great customer service, a clean and safe place to stay.  Thank you to all our guests and repeat customers! ', 'data_to_embed': "DENVER SUITE MOUNTAIN VIEW GREAT LOCATION DENVER SUITE WITH A MOUNTAIN VIEW: live in the very heart of downtown and enjoy a beautiful and peaceful mountain view!  Fully furnished 2 bedroom / 2 bathroom suite with an open plan living/dining room furnished with contemporary leather furniture and original artwork.  Perfect for an extended stay for a small family or a business traveler. IDEAL LOCATION: Walk out of this suite, take the elevator down, step through the lobby and you are THERE, truly in DOWNTOWN! The Performing Arts Center is just a half-block away. The Convention C ...
# Iteration: 3, has handled 45 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67288be6f310036be2627a88'), 'id': '1309159', 'listing_url': 'https://www.airbnb.com/rooms/1309159', 'source': 'city scrape', 'name': 'Logan Square Studio APT #3 - w/clawfoot tub', 'description': 'APT 3 is a ~300 sq ft studio on the second floor.  The large bathroom features the original cast iron tub refinished with all new hardware and shower.  The studio space comfortably fits a queen size bed, dresser, two sitting chairs, and a large adjustable table that can be used for dining or desk work.', 'neighborhood_overview': 'Walk Score - 93<br />In Northwest Cap Hill<br />Blocks from the Capitol and Civic Center Park<br />Easy walk to downtown Denver, Golden Triangle, South Broadway, Cap Hill, Cheeseman Park, upTown 17th St Restaurants and Ace Ping Pong and One Up Arcade Bar.  Easy walk to Fillmore and Ogden Theater.', 'latitude': '39.73444082066197', 'longitude': '-104.98377035083135', 'price': '$65.00', 'amenities': '["Hangers", "Essentials", "Dishwasher", "Toaster", "Barbecue utensils", "Microwave", "Shampoo", "Hair dryer", "Oven", "Baking sheet", "Dishes and silverware", "Ethernet connection", "Air conditioning", "Shared backyard \\u2013 Fully fenced", "Smoke alarm", "Clothing storage", "Blender", "Dining table", "Freezer", "First aid kit", "Body soap", "Shower gel", "Carbon monoxide alarm", "Fire extinguisher", "Wine glasses", "Luggage dropoff allowed", "Washer", "Pets allowed", "Outdoor dining area", "Cleaning products", "Heating", "Kitchen", "Refrigerator", "Cooking basics", "Extra pillows and blankets", "Hot water", "Drying rack for clothing", "Coffee maker", "BBQ grill", "Laundromat nearby", "Dryer", "Free street parking", "Window guards", "Ceiling fan", "Bathtub", "Long term stays allowed", "Rice maker", "Conditioner", "Outdoor furniture", "Iron", "Hot water kettle", "Coffee", "Stove", "Wifi", "Bed linens", "Exterior security cameras on property", "TV"]', 'beds': '2', 'bedrooms': '0', 'bathrooms': '1.0', 'bathrooms_text': '1 bath', 'property_type': 'Entire rental unit', 'room_type': 'Entire home/apt', 'host_about': 'Hello!  My name is Joe.  \n\nI like to play music, snowboard, ride bikes, eat delicious food, practice yoga, be outside and grow things!\n\nCheers!', 'data_to_embed': 'Logan Square Studio APT #3 - w/clawfoot tub APT 3 is a ~300 sq ft studio on the second floor.  The large bathroom features the original cast iron tub refinished with all new hardware and shower.  The studio space comfortably fits a queen size bed, dresser, two sitting chairs, and a large adjustable table that can be used for dining or desk work. Walk Score - 93<br />In Northwest Cap Hill<br />Blocks from the Capitol and Civic Center Park<br />Easy walk to downtown Denver, Golden Triangle, South Broadway, Cap Hill, Cheeseman Park, upTown 17th St Restaurants and Ace Ping Pong and One Up Arcade Bar.  Easy walk to Fillmore and Ogden Theater.'}, {'_id': ObjectId('67288be6f310036be2627a89'), 'id': '1311993', 'listing_url': 'https://www.airbnb.com/rooms/1311993', 'source': 'city scrape', 'name': 'Downtown Apt - Clean & Convenient! Brooks Tower 5I', 'description': 'Located in downtown Denver, unit 5I is in the thick of city action. Walk to Elitch Gardens, Pepsi Center, Coors Field, Empower at Mile High Stadium, historic Union Station, Denver Performing Arts Complex, Auraria Campus, and more. Fully furnished studio apartment with private balcony, DIRECTV, WiFi, outdoor pool, gym, billiards room, 24/7 front desk staff and secured building access. <br /><br />Coin operated on-site laundry is currently limited, but pickup laundry service on site is available.', 'neighborhood_overview': 'Located in the Central Business District. Easy stroll to LoDo nightlife, bars, and restaurants. <br /><br />Super Target just four blocks away. Take the FREE 16th St Mall shuttle to Whole Foods and King Soopers.', 'latitude': '39.74634', 'longitude': '-104.99678', 'price': '$89.00', 'amenities': '["Hangers", "Essentials", "Dishwasher", "Microwave", "Paid ...
# Iteration: 4, has handled 60 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67288be6f310036be2627a96'), 'id': '1733052', 'listing_url': 'https://www.airbnb.com/rooms/1733052', 'source': 'city scrape', 'name': 'Beautiful Private Basement Suite near Downtown', 'description': 'Beautifully remodeled basement suite in lovely Victorian home in central Denver.', 'neighborhood_overview': 'Many historical homes with a beautiful park nearby. Tons of ethnic restaurants, museums, and places of interest within walking distance from our address. There are 4 breweries within a mile; another 6 breweries within 2 miles. Excellent music venues are close by; 2 (Fillmore and Ogden Theater) are a couple blocks away. Public transportation and bike rentals are convenient from our location.', 'latitude': '39.73799', 'longitude': '-104.97219', 'price': '$103.00', 'amenities': '["Hangers", "Essentials", "Dishwasher", "Books and reading material", "Toaster", "Barbecue utensils", "Children\\u2019s dinnerware", "Microwave", "Shampoo", "Hair dryer", "Stainless steel gas stove", "Baking sheet", "Dishes and silverware", "Ethernet connection", "Shared backyard \\u2013 Fully fenced", "Self check-in", "Smoke alarm", "Fast wifi \\u2013 207 Mbps", "Blender", "Dining table", "Portable fans", "Board games", "Freezer", "Smart lock", "Outlet covers", "First aid kit", "Body soap", "Shower gel", "Carbon monoxide alarm", "Fire extinguisher", "Wine glasses", "Luggage dropoff allowed", "Outdoor dining area", "Cleaning products", "Shared patio or balcony", "Heating", "Kitchen", "Fire pit", "Refrigerator", "Mini fridge", "Cooking basics", "Extra pillows and blankets", "Stainless steel single oven", "Hot water", "Coffee maker", "Clothing storage: closet", "Free washer \\u2013 In unit", "Lock on bedroom door", "Laundromat nearby", "BBQ grill", "Central air conditioning", "Free street parking", "Bathtub", "Room-darkening shades", "Conditioner", "Outdoor furniture", "Iron", "Hot water kettle", "Coffee", "Private living room", "Pack \\u2019n play/Travel crib", "Bed linens", "Free dryer \\u2013 In unit", "TV"]', 'beds': '5', 'bedrooms': '1', 'bathrooms': '1.0', 'bathrooms_text': '1 private bath', 'property_type': 'Private room in home', 'room_type': 'Private room', 'host_about': 'I enjoy traveling and exploration; mountain climbing and the outdoors. I work in the medical field as a Medical Physicist in Radiation Oncology. I have been living in Denver for about 20 years. I like mountaineering quite a bit and have climbed the highest mountain on 3 continents. I love to see and experience different cultures and beautiful landscapes. In 2012, I married Vibeke, and we are happily living in central Denver and enjoy cooking and the outdoors together.', 'data_to_embed': 'Beautiful Private Basement Suite near Downtown Beautifully remodeled basement suite in lovely Victorian home in central Denver. Many historical homes with a beautiful park nearby. Tons of ethnic restaurants, museums, and places of interest within walking distance from our address. There are 4 breweries within a mile; another 6 breweries within 2 miles. Excellent music venues are close by; 2 (Fillmore and Ogden Theater) are a couple blocks away. Public transportation and bike rentals are convenient from our location.'}, {'_id': ObjectId('67288be6f310036be2627a97'), 'id': '1737365', 'listing_url': 'https://www.airbnb.com/rooms/1737365', 'source': 'city scrape', 'name': 'Stylish & Historic LoHi Loft on Wyandot', 'description': 'Quiet, spacious, renovated 800 sf loft studio in a prime LoHi location.  Historic building on tree lined street. New appliances, Restoration Hardware bedding and furniture.  Private outdoor balcony overlooking lush shared backyard space.  Enjoy a quiet retreat on the best block in LoHi!', 'neighborhood_overview': "The apartment is a five-minute drive to downtown, and is easily walking distance on a nice day. It's on a beautiful tree-lined street that is quiet and upscale. Lots of restaurants and shops are within walking distance.", 'latitude': '39.75901',  ...
# Iteration: 5, has handled 75 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67288be6f310036be2627aa5'), 'id': '2232323', 'listing_url': 'https://www.airbnb.com/rooms/2232323', 'source': 'city scrape', 'name': 'Cozy Cottage in the Country Club,', 'description': 'You will enjoy my cozy home in the Country Club area.  The home is a 3 bed/3 bath with 2 bedrooms and a bath on the garden level.  The neighborhood is easily walkable to Cherry Creek and Capitol Hill restaurants and shopping.<br />', 'neighborhood_overview': 'Friendly with families of all ages who will say hi.', 'latitude': '39.72367', 'longitude': '-104.96557', 'price': '$260.00', 'amenities': '["Dedicated workspace", "Microwave", "Private backyard \\u2013 Fully fenced", "Dishes and silverware", "Air conditioning", "Indoor fireplace", "Smoke alarm", "Fireplace guards", "First aid kit", "Carbon monoxide alarm", "Fire extinguisher", "Washer", "Cleaning products", "Heating", "Kitchen", "Refrigerator", "TV with standard cable", "Cooking basics", "Extra pillows and blankets", "Coffee maker", "BBQ grill", "Dryer", "Free street parking", "Garden view", "Patio or balcony", "Room-darkening shades", "Outdoor furniture", "Free parking on premises", "Stove", "Wifi"]', 'beds': '3', 'bedrooms': '3', 'bathrooms': '3.0', 'bathrooms_text': '3 baths', 'property_type': 'Entire home', 'room_type': 'Entire home/apt', 'host_about': "Having worked in non-profit world in management for 30 years I am passionate about arts and culture, reading and especially PBS and NPR, educational programming where I spent the last decade + of my formal working career. I am an easy host, not usually on the premises but this is my primary home so I do have a separate room  on a different level if I have to be there. Anxious to tout Colorado's special beauty and wonderful mountain towns, I can be directing you to all things out of th way and fun in the city and special destinations west of here. ", 'data_to_embed': 'Cozy Cottage in the Country Club, You will enjoy my cozy home in the Country Club area.  The home is a 3 bed/3 bath with 2 bedrooms and a bath on the garden level.  The neighborhood is easily walkable to Cherry Creek and Capitol Hill restaurants and shopping.<br /> Friendly with families of all ages who will say hi.'}, {'_id': ObjectId('67288be6f310036be2627aa6'), 'id': '2235726', 'listing_url': 'https://www.airbnb.com/rooms/2235726', 'source': 'city scrape', 'name': 'Executive LODO Loft', 'description': 'Executive loft across from Coors Field and the new McGregor’s Square. Two large patios with views of Coors Field, gourmet kitchen with all the tools. Two blocks from Union Station and within walking distance of hundreds of restaurants, bars and a variety of entertainment.', 'neighborhood_overview': 'Downtown Denver, LODO', 'latitude': '39.75392809200818', 'longitude': '-104.99667984547165', 'price': '$250.00', 'amenities': '["Hangers", "Essentials", "Dishwasher", "Books and reading material", "Dedicated workspace", "Toaster", "Coffee maker: espresso machine, french press", "Microwave", "Barbecue utensils", "Exercise equipment: free weights, stationary bike, treadmill, workout bench", "Baking sheet", "Dishes and silverware", "City skyline view", "Free carport on premises \\u2013 1 space", "Private sauna", "Smoke alarm", "Blender", "Board games", "Freezer", "Clothing storage: wardrobe", "First aid kit", "Private patio or balcony", "Body soap", "Bread maker", "Carbon monoxide alarm", "Fire extinguisher", "Wine glasses", "Elevator", "Outdoor dining area", "Cleaning products", "60 inch HDTV with Amazon Prime Video, Apple TV, Disney+, HBO Max, Hulu, Netflix", "Kitchen", "Gas stove", "Refrigerator", "Cooking basics", "Extra pillows and blankets", "Private BBQ grill: gas", "Game console: PS4", "Hot water", "Sound system", "Free washer \\u2013 In unit", "Stainless steel oven", "Dryer", "Central air conditioning", "Long term stays allowed", "Conditioner", "Outdoor furniture", "Central heating", "Iron", "Bidet", "Coffee", "Wifi", "Bed linens"]', 'beds': '2', 'bedro ...
# Iteration: 6, has handled 90 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67288be6f310036be2627ab5'), 'id': '3150813', 'listing_url': 'https://www.airbnb.com/rooms/3150813', 'source': 'city scrape', 'name': 'Modern Urban Oasis in Rino', 'description': "This is a converted 2500 square foot modern industrial loft space on a beautiful double 10,000 square foot lot in a great part of town. New places opening daily here. A-line Blake New Mission Ballroom is a short walk!<br /><br /> Super tall ceilings, reclaimed wood floors,   mid-century modern, eclectic, bohemian vibe. It's equipped with an amazing sound system and commercial grade kitchen as well as spacious side yard with a fire pit. Ideal for large groups, reunions, and the like.", 'neighborhood_overview': 'Very close to the A-line Blake street stop from the airport. So many hip, new things to do in the neighborhood including the brand new Mission Ballroom which is only blocks away. The house sits in one of the coolest neighborhoods, Rino District, in Denver, close to downtown and a bevy of restaurants, bars, and cultural activities.', 'latitude': '39.77101', 'longitude': '-104.96639', 'price': '$426.00', 'amenities': '["Hangers", "Essentials", "Dishwasher", "Dedicated workspace", "Smoking allowed", "Microwave", "Shampoo", "Hair dryer", "Oven", "Dishes and silverware", "Air conditioning", "Self check-in", "Smoke alarm", "Smart lock", "First aid kit", "Carbon monoxide alarm", "Fire extinguisher", "Luggage dropoff allowed", "Washer", "Pets allowed", "Heating", "Kitchen", "Fire pit", "Refrigerator", "TV with standard cable", "Cooking basics", "Backyard", "Hot water", "Coffee maker", "BBQ grill", "Dryer", "Free street parking", "Long term stays allowed", "Patio or balcony", "Room-darkening shades", "Outdoor furniture", "Free parking on premises", "Iron", "Stove", "Wifi", "Exterior security cameras on property", "Bathtub"]', 'beds': '3', 'bedrooms': '2', 'bathrooms': '2.0', 'bathrooms_text': '2 baths', 'property_type': 'Entire home', 'room_type': 'Entire home/apt', 'host_about': "I'm a high school teacher in Denver. I teach media and pop culture. ", 'data_to_embed': "Modern Urban Oasis in Rino This is a converted 2500 square foot modern industrial loft space on a beautiful double 10,000 square foot lot in a great part of town. New places opening daily here. A-line Blake New Mission Ballroom is a short walk!<br /><br /> Super tall ceilings, reclaimed wood floors,   mid-century modern, eclectic, bohemian vibe. It's equipped with an amazing sound system and commercial grade kitchen as well as spacious side yard with a fire pit. Ideal for large groups, reunions, and the like. Very close to the A-line Blake street stop from the airport. So many hip, new things to do in the neighborhood including the brand new Mission Ballroom which is only blocks away. The house sits in one of the coolest neighborhoods, Rino District, in Denver, close to downtown and a bevy of restaurants, bars, and cultural activities."}, {'_id': ObjectId('67288be6f310036be2627ab6'), 'id': '3280778', 'listing_url': 'https://www.airbnb.com/rooms/3280778', 'source': 'city scrape', 'name': 'Art Deco Boho close to everything!', 'description': 'Welcome to your centrally located stunningly remodeled home. This luxurious bohemian art deco farmhouse has all you need to enjoy your stay while in Denver.<br /><br />You can make this basecamp for all your Denver Adventures. With close access to the main arteries of town you can quickly head to the mountains to enjoy Red Rocks Amphitheater and foothills, go downtown or South Broadway in a flash. This neighborhood has some of the most authentic ethnic food choices in the city! Pickleball 3 blocks away!', 'neighborhood_overview': 'Athmar Park', 'latitude': '39.70719', 'longitude': '-105.01878', 'price': '$306.00', 'amenities': '["Hangers", "Essentials", "Clothing storage: walk-in closet, closet, and dresser", "Dedicated workspace", "Dishwasher", "Toaster", "Microwave", "Shampoo", "Hair dryer", "Private backyard \\u2013 Fully fenced", "S ...
# Iteration: 7, has handled 105 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67288be6f310036be2627ac4'), 'id': '3891080', 'listing_url': 'https://www.airbnb.com/rooms/3891080', 'source': 'city scrape', 'name': 'Charming vintage Five Points apt', 'description': 'Welcome to the HEART of Five Points , the closest neighborhood to DOWNTOWN Denver - a walker’s and scooter/bike/ride share person’s CITY PARADISE. Blocks away from lively RINO arts district, Curtis Park, grocery, and SO many unique restaurants, coffee shops, brewpubs, along with easy access to the interstate for additional Colorado adventures. You can check off LOCATION with this rental! <br />This well appointed and charming vintage apartment is in our 1887 Victorian home and occupies the top floor.', 'neighborhood_overview': '', 'latitude': '39.75229', 'longitude': '-104.97978', 'price': '$110.00', 'amenities': '["Hangers", "Essentials", "Clothing storage: walk-in closet and dresser", "Dedicated workspace", "Microwave", "Hair dryer", "Oven", "Terra Pure conditioner", "Dishes and silverware", "Air conditioning", "Self check-in", "Smoke alarm", "Freezer", "Private patio or balcony", "Body soap", "Carbon monoxide alarm", "Fire extinguisher", "Outdoor dining area", "Terra Pure shampoo", "Lockbox", "Heating", "Kitchen", "Gas stove", "Refrigerator", "TV with standard cable", "Cooking basics", "Hot water", "Free street parking", "Ceiling fan", "Wifi", "Bathtub"]', 'beds': '2', 'bedrooms': '1', 'bathrooms': '1.0', 'bathrooms_text': '1 bath', 'property_type': 'Entire home', 'room_type': 'Entire home/apt', 'host_about': 'Mom, wife, nurse practitioner, short term rental host. Doing my best to live consciously and courageously with kindness and compassion. Enjoy living and working in downtown Denver with generous side adventures to the great Colorado outdoors!', 'data_to_embed': 'Charming vintage Five Points apt Welcome to the HEART of Five Points , the closest neighborhood to DOWNTOWN Denver - a walker’s and scooter/bike/ride share person’s CITY PARADISE. Blocks away from lively RINO arts district, Curtis Park, grocery, and SO many unique restaurants, coffee shops, brewpubs, along with easy access to the interstate for additional Colorado adventures. You can check off LOCATION with this rental! <br />This well appointed and charming vintage apartment is in our 1887 Victorian home and occupies the top floor. '}, {'_id': ObjectId('67288be6f310036be2627ac5'), 'id': '3960763', 'listing_url': 'https://www.airbnb.com/rooms/3960763', 'source': 'city scrape', 'name': "Relax in Denver's Best Neighborhood Platt Park!", 'description': 'If you are staying July 23 to July 27th I have lowered the price of the property to 150.00$. Email me for details.   Stay close to downtown. This property is in south-central Denver and is close to Downtown, and is 20 minutes from Dicks Sporting Goods Park and Red Rocks. This is a family-friendly home.  This neighborhood is the best in Denver for nightlife and activities.  I live in a quiet area, if you are looking for a party house this is not the rental that you are looking for.', 'neighborhood_overview': "The Neighborhood: Platt Park<br />At the turn of the 20th century, the Platt Park neighborhood—then a separate city from Denver—was a bustling borough of five-and-dime shops and sprawling family homes connected to the city by a clanking trolley line that ran up Pearl Street. As the Mile High City grew, the neighborhood was incorporated, and Denverites migrated south to make it their home. Today, the neighborhood’s storied history is still visible on Pearl Street, where visitors can glimpse trolley tracks peeking through the asphalt overlay, and new shops and purveyors occupy the original, historic buildings.<br /><br /><br />Platt Park is a pedestrian friendly neighborhood.  One block from Antique Row on Broadway with bars and retail.  5 blocks from South Pearl St.<br />(URL HIDDEN)<br /><br />15 minute walk to the Light Rail at Louisiana/Pearl St. Station.<br />(URL HIDDEN)<br /><br />5 Blocks from The Sushi D ...
# Iteration: 8, has handled 120 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67288be6f310036be2627ad2'), 'id': '4350594', 'listing_url': 'https://www.airbnb.com/rooms/4350594', 'source': 'city scrape', 'name': 'Kid Friendly Home-Great Location with Sauna', 'description': "Charming home in great Denver neighborhood. 2 minute walk to a park with new play structures, 20 min walk (4 min drive) to French bakery, great coffee, movie theater, great restaurants & Trader Joe's. 15 min drive downtown Den, 10 min drive Denver Zoo & Museum of Nature & Science, 8 min drive Cherry Creek North (shopping, restaurants, bars) & Denver Botanic Gardens.", 'neighborhood_overview': '', 'latitude': '39.72904', 'longitude': '-104.92346', 'price': '$175.00', 'amenities': '["Hangers", "Essentials", "Dishwasher", "Dedicated workspace", "Toaster", "Children\\u2019s dinnerware", "Shampoo", "Hair dryer", "Oven", "Baking sheet", "Private backyard \\u2013 Fully fenced", "Dishes and silverware", "Self check-in", "Private sauna", "Indoor fireplace: wood-burning", "Smoke alarm", "Dining table", "Blender", "Freezer", "Private patio or balcony", "Carbon monoxide alarm", "Fire extinguisher", "Luggage dropoff allowed", "Lockbox", "Heating", "Kitchen", "Coffee maker: pour-over coffee", "Refrigerator", "Cooking basics", "Extra pillows and blankets", "Hot water", "BBQ grill", "52 inch HDTV with Amazon Prime Video, Apple TV, Disney+", "Free washer \\u2013 In unit", "Dryer", "Central air conditioning", "Free street parking", "Long term stays allowed", "High chair", "Room-darkening shades", "Rice maker", "Outdoor furniture", "Free parking on premises", "Iron", "Hot water kettle", "Children\\u2019s books and toys", "Stove", "Wifi", "Bed linens"]', 'beds': '4', 'bedrooms': '4', 'bathrooms': '1.0', 'bathrooms_text': '1 bath', 'property_type': 'Entire home', 'room_type': 'Entire home/apt', 'host_about': "My husband and I live with, our two sons & our daughter in Denver, CO.  We've lived in a few different cities including Phoenix, Seattle & Brooklyn and have enjoyed every minute of it before settling back into our home state of beautiful Colorado.  We absolutely love to cook, travel, experience new things and meet new people!", 'data_to_embed': "Kid Friendly Home-Great Location with Sauna Charming home in great Denver neighborhood. 2 minute walk to a park with new play structures, 20 min walk (4 min drive) to French bakery, great coffee, movie theater, great restaurants & Trader Joe's. 15 min drive downtown Den, 10 min drive Denver Zoo & Museum of Nature & Science, 8 min drive Cherry Creek North (shopping, restaurants, bars) & Denver Botanic Gardens. "}, {'_id': ObjectId('67288be6f310036be2627ad3'), 'id': '4384783', 'listing_url': 'https://www.airbnb.com/rooms/4384783', 'source': 'city scrape', 'name': 'Sunny Condo! Close To Downtown!', 'description': "Our condo is available all year round for workers and visitors traveling to Denver. Minimum stay is 29 nights. Loaded with comfortable furnishings, you'll find everything you need to make your stay enjoyable and comfortable! Please note: no pets allowed due to allergies.", 'neighborhood_overview': "The Hale neighborhood in Denver is unique because of it's more affordable housing and easy access to the more popular (but more expensive) Congress Park district. But that is all about to change because the immediate 36 acres surrounding this condo is undergoing a massive redevelopment lead by the city of Denver and is set to be the next up and coming hotspot for young professionals.", 'latitude': '39.73116', 'longitude': '-104.93282', 'price': '$85.00', 'amenities': '["Hangers", "Essentials", "Dishwasher", "Books and reading material", "Dedicated workspace", "Toaster", "Barbecue utensils", "Children\\u2019s dinnerware", "Microwave", "Shampoo", "Hair dryer", "Oven", "Pack \\u2019n play/Travel crib - available upon request", "Clothing storage: closet and dresser", "Dishes and silverware", "Baking sheet", "Shared BBQ grill: gas", "Ethernet connection", "Air conditioning", "Self check-in", "S ...
# Iteration: 9, has handled 135 rows

# %%
# list all the indexes

indexes = collection.list_indexes()

for index in indexes:
    print(index)
# Out:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('embeddings', 'cosmosSearch')])), ('name', 'listingIndex'), ('cosmosSearchOptions', SON([('kind', 'vector-diskann'), ('numLists', 1), ('similarity', 'COS'), ('dimensions', 1536)]))])
