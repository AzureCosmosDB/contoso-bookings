# %% [markdown]
# # Vector Search with AutoEmbedding Demo
# Data Prep and Upload

# %%
import os
import json
from pymongo import MongoClient
from dotenv import load_dotenv
load_dotenv()
VCORE_URL = os.environ["VCORE_URL"]
AOAI_ENDPOINT = os.environ["AOAI_ENDPOINT"]
AOAI_KEY = os.environ["AOAI_KEY"]
db_name = 'yelp_dataset'

client = MongoClient(VCORE_URL)
db = client[db_name]
collection = db['business']


# Check if the data already exists in the database
if db_name in client.list_database_names():
    print(f"Database '{db_name}' exists. Skipping data upload.")
else:
    print(f"Preparing data upload to '{db_name}' database.")

    batch_size = 1000
    json_file_path = './datasets without embeddings\yelp_academic_dataset.business.json'
    
    with open(json_file_path, 'r', encoding="utf-8") as file:
        data = json.load(file)

    for i in range(0, len(data), batch_size):
        batch = data[i:i + batch_size]
        collection.insert_many(batch)
        print(f"Inserted batch {i // batch_size + 1}")
# Out:
# Database 'yelp_dataset' exists. Skipping data upload.

# %% [markdown]
# ## I. Auto-embedding generation
# Generate embeddings for records that do not have embeddings yet

# %%
import time
from pymongo import UpdateOne
batch_size = 15
total_updated = 0
iteration = 0

while True:
    iteration += 1

    # Find records to update
    records_to_update = collection.find({
        '$and': [
            {'embeddings': {'$exists': False}},
            {'description': {'$exists': True}}
        ]
    }).limit(batch_size)
    records_to_update = list(records_to_update)
    print(records_to_update)

    if not records_to_update:
        print(f"All rows have been updated. Total updated rows: {total_updated}")
        break

    total_updated += len(records_to_update)

    print(f"Iteration: {iteration}, has handled {total_updated} rows")

    # Prepare bulk operations
    bulk_ops = [
        UpdateOne({'_id': record['_id']},
                {'$generateEmbeddings': {'description': 'embeddings'}})
        for record in records_to_update
    ]

    if bulk_ops:
        result = db.business.bulk_write(bulk_ops)
        print(f"Bulk write result: {result.bulk_api_result}")

    time.sleep(0.5)  # Sleep for 500 ms
# Out:
# [{'_id': ObjectId('671b4443efc3fbf09a7d44be'), 'business_id': 'e31Rd2X0KYAS54ciEtsZyg', 'name': 'Green Taxi', 'address': '3340 McCaw Ave, Ste 114', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4384349379, 'longitude': -119.7362903171, 'stars': 2, 'review_count': 12, 'is_open': 1, 'attributes': None, 'categories': 'Hotels & Travel, Transportation, Taxis', 'hours': None, 'location': {'type': 'Point', 'coordinates': [-119.7362903171, 34.4384349379]}, 'description': "Green Taxi, located at 3340 McCaw Ave, Ste 114 in Santa Barbara, CA, is a taxi service that falls under the categories of Hotels & Travel, Transportation, and Taxis. With a modest rating of 2 stars based on 12 reviews, Green Taxi offers essential transportation services to the Santa Barbara area. Despite its lower rating, it remains operational and serves the community's travel needs. The business is situated conveniently with coordinates at a latitude of 34.4384349379 and a longitude of -119.7362903171."}, {'_id': ObjectId('671b4442efc3fbf09a7d41bc'), 'business_id': '4EVaX7MAbeZZRWBx33jx3A', 'name': 'Gold Coast Locksmith', 'address': '', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4208305, 'longitude': -119.6981901, 'stars': 4.5, 'review_count': 48, 'is_open': 1, 'attributes': {'BusinessAcceptsCreditCards': 'True', 'ByAppointmentOnly': 'False'}, 'categories': 'Keys & Locksmiths, Home Services, Security Services, Professional Services', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'Wednesday': '0:0-0:0', 'Thursday': '0:0-0:0', 'Friday': '0:0-0:0', 'Saturday': '0:0-0:0', 'Sunday': '0:0-0:0'}, 'location': {'type': 'Point', 'coordinates': [-119.6981901, 34.4208305]}, 'description': "Gold Coast Locksmith, located in Santa Barbara, CA, is a highly-rated locksmith service with a 4.5-star rating based on 48 reviews. Specializing in keys, locksmithing, and security services, this professional business is dedicated to providing top-tier home services. With the convenience of accepting credit cards and offering services without the need for appointments, Gold Coast Locksmith ensures accessibility and customer satisfaction. Whether you're in need of urgent lockout assistance or comprehensive security solutions, this reputable locksmith is open and ready to serve the Santa Barbara community."}, {'_id': ObjectId('671b4442efc3fbf09a7d41ef'), 'business_id': 'jhLOl7Z2fnYftTphwPi7Qg', 'name': 'Waterhouse Gallery', 'address': '1114 State St, Ste 9', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93101', 'latitude': 34.4231054, 'longitude': -119.7035993, 'stars': 4.5, 'review_count': 11, 'is_open': 1, 'attributes': {'BikeParking': 'True', 'ByAppointmentOnly': 'False', 'RestaurantsPriceRange2': '3', 'GoodForKids': 'False', 'WheelchairAccessible': 'True', 'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}", 'DogsAllowed': 'True', 'BusinessAcceptsCreditCards': 'True'}, 'categories': 'Shopping, Art Galleries, Arts & Entertainment', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '11:0-17:0', 'Wednesday': '11:0-17:0', 'Thursday': '11:0-17:0', 'Friday': '11:0-17:0', 'Saturday': '11:0-17:0', 'Sunday': '12:0-16:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7035993, 34.4231054]}, 'description': 'Waterhouse Gallery, located at 1114 State St, Ste 9, in Santa Barbara, CA, is a distinguished art gallery that has earned a 4.5-star rating from 11 reviews. Specializing in Shopping, Art Galleries, and Arts & Entertainment, this gallery offers a rich collection of artistic works and a welcoming environment for art enthusiasts. Open six days a week, with hours from 11:00 AM to 5:00 PM Tuesday through Saturday and 12:00 PM to 4:00 PM on Sunday, the gallery is accessible and convenient. Waterhouse Gallery is wheelchair accessible, offers bike parking, and accommodates dogs, making it an inclusive space for all visitors. Additionally, it provides garage parking and ac ...
# Iteration: 1, has handled 15 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 15, 'nModified': 15, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('671b4443efc3fbf09a7d4594'), 'business_id': 'CkENBnSJFfPA1hY0qrqfCg', 'name': 'Carlitos Cafe Y Cantina', 'address': '1324 State St, Ste A', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93101', 'latitude': 34.42505409, 'longitude': -119.7065041501, 'stars': 3.5, 'review_count': 731, 'is_open': 1, 'attributes': {'RestaurantsAttire': "'casual'", 'RestaurantsGoodForGroups': 'True', 'BusinessAcceptsCreditCards': 'True', 'GoodForKids': 'True', 'OutdoorSeating': 'True', 'RestaurantsPriceRange2': '2', 'BikeParking': 'True', 'RestaurantsReservations': 'True', 'WiFi': "u'free'", 'RestaurantsTakeOut': 'True', 'Alcohol': "'full_bar'", 'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': True}", 'DogsAllowed': 'True', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}", 'HasTV': 'False', 'RestaurantsTableService': 'True', 'NoiseLevel': "u'average'", 'WheelchairAccessible': 'True', 'HappyHour': 'True', 'Caters': 'False', 'DriveThru': 'False', 'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': None, 'breakfast': False}", 'RestaurantsDelivery': 'None'}, 'categories': 'Restaurants, Mexican', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', 'Wednesday': '11:0-22:0', 'Thursday': '11:0-22:0', 'Friday': '11:0-22:0', 'Saturday': '11:0-22:0', 'Sunday': '11:0-22:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7065041501, 34.42505409]}, 'description': 'Carlitos Cafe Y Cantina, located at 1324 State St, Ste A in Santa Barbara, CA, is a popular Mexican restaurant known for its casual and family-friendly atmosphere. With a 3.5-star rating and 731 reviews, this establishment is well-regarded for its outdoor seating, full bar, and accommodating service for groups and kids. Open every day from 11:00 AM to 10:00 PM, Carlitos Cafe Y Cantina offers a range of dining options including lunch and dinner, with the convenience of takeout and reservations. The restaurant features amenities such as free WiFi, bike parking, and wheelchair accessibility, ensuring a comfortable experience for all guests. Additionally, the venue is dog-friendly and offers a happy hour, making it a versatile spot for various dining occasions.'}, {'_id': ObjectId('671b4443efc3fbf09a7d45b9'), 'business_id': 'FAabASyk_4p5UrUnUtyvpw', 'name': 'Aae Santa Barbara', 'address': '111 N Milpas St', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93103', 'latitude': 34.4227504, 'longitude': -119.6808805, 'stars': 2, 'review_count': 7, 'is_open': 0, 'attributes': None, 'categories': 'Hotels & Travel, Hostels', 'hours': None, 'location': {'type': 'Point', 'coordinates': [-119.6808805, 34.4227504]}, 'description': 'Aae Santa Barbara, located at 111 N Milpas St in Santa Barbara, CA, was a business specializing in the "Hotels & Travel" sector, specifically offering hostel accommodations. Despite its convenient location in the picturesque city of Santa Barbara, the establishment garnered an average rating of 2 stars based on 7 reviews. Currently closed, Aae Santa Barbara provided a budget-friendly lodging option for travelers.'}, {'_id': ObjectId('671b4443efc3fbf09a7d450e'), 'business_id': 'loO2JtNBozlg8xpd_suebg', 'name': "Who's Walking Who", 'address': '', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93109', 'latitude': 34.4038383, 'longitude': -119.7252297, 'stars': 5, 'review_count': 11, 'is_open': 1, 'attributes': None, 'categories': 'Pet Sitting, Dog Walkers, Pet Services, Pets, Pet Transportation', 'hours': {'Monday': '8:0-20:0', 'Tuesday': '8:0-20:0', 'Wednesday': '8:0-20:0', 'Thursday': '8:0-20:0', 'Friday': '8:0-20:0', 'Saturday': '8:0-20:0', 'Sunday': '8:0-20:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7252297, 34.4038383]}, 'description': '### Business Summary\n\nLocated in the beautiful city of Santa Barbara, CA, ...
# Iteration: 2, has handled 20 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 5, 'nModified': 5, 'nRemoved': 0, 'upserted': []}
# []
# All rows have been updated. Total updated rows: 20

# %%
# query data
result = collection.find_one({
    "city": "Santa Barbara",
    "postal_code": "93105"
})

# Print the result
if result:
    business_embed = result.pop("embeddings")
    print(result)
# Out:
# {'_id': ObjectId('671b4443efc3fbf09a7d46ce'), 'business_id': 'gfjjUlMC05kry6qjYyKrcA', 'name': 'West Coast Vascular', 'address': '2323 Oak Park Ln, Ste 201', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4287211, 'longitude': -119.7250939, 'stars': 2, 'review_count': 5, 'is_open': 1, 'attributes': {'BusinessAcceptsCreditCards': 'False'}, 'categories': 'Health & Medical, Doctors, Vascular Medicine, Medical Centers, Surgeons', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'Wednesday': '0:0-0:0', 'Thursday': '0:0-0:0', 'Friday': '0:0-0:0', 'Saturday': '0:0-0:0', 'Sunday': '0:0-0:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7250939, 34.4287211]}, 'description': 'West Coast Vascular, located at 2323 Oak Park Ln, Ste 201, Santa Barbara, CA 93105, is a specialized medical center focusing on vascular medicine and surgery. Despite its convenient location and comprehensive services in the health and medical sectors, including doctors and surgeons, it has received a modest rating of 2 stars based on 5 reviews. Notably, the facility does not accept credit cards. Although it is listed as open, the business hours are unspecified, indicating it may operate on an appointment-only basis.'}

# %% [markdown]
# ### II. Query Data
# a. GeoSpacial Query
# find nearby stores based on geographic proximity

# %%
# create index
command = {
    "createIndexes": "business",
    "indexes": [
        {
            "key": {
                "location": "2dsphere"
            },

            "name": "location_index"
        }
    ]

}
db.command(command)
# Out:
# {'raw': {'defaultShard': {'numIndexesBefore': 5,
#    'numIndexesAfter': 5,
#    'createdCollectionAutomatically': False,
#    'note': 'all indexes already exist',
#    'ok': 1}},
#  'ok': 1}

# %%
# Define the user's location
user_location = {
    "type": "Point",
    "coordinates": [-119.7250939, 34.4287211]  # User's location (longitude, latitude)
}

# Perform the aggregation with $geoNear
pipeline = [
    {
        "$geoNear": {
            "key": "location",
            "near": user_location,
            "distanceField": "distance",  # Field to store the calculated distance
            "maxDistance": 5,  # Maximum distance in meters (5 km)
            "spherical": True,  # Use spherical geometry
            "$match": {
                "isOpen": True,  # Filter for open restaurants
                "stars": {"$gte": 2}  # Filter by rating >= 2
            },
            "$limit": 5  # Limit to top 5 results
        }
    }
]

# Execute the aggregation
results = collection.aggregate(pipeline)

# Print the results
for doc in results:
    doc.pop("embeddings")
    print(doc)
# Out:
# {'_id': ObjectId('671b4443efc3fbf09a7d46ce'), 'business_id': 'gfjjUlMC05kry6qjYyKrcA', 'name': 'West Coast Vascular', 'address': '2323 Oak Park Ln, Ste 201', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4287211, 'longitude': -119.7250939, 'stars': 2, 'review_count': 5, 'is_open': 1, 'attributes': {'BusinessAcceptsCreditCards': 'False'}, 'categories': 'Health & Medical, Doctors, Vascular Medicine, Medical Centers, Surgeons', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'Wednesday': '0:0-0:0', 'Thursday': '0:0-0:0', 'Friday': '0:0-0:0', 'Saturday': '0:0-0:0', 'Sunday': '0:0-0:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7250939, 34.4287211]}, 'description': 'West Coast Vascular, located at 2323 Oak Park Ln, Ste 201, Santa Barbara, CA 93105, is a specialized medical center focusing on vascular medicine and surgery. Despite its convenient location and comprehensive services in the health and medical sectors, including doctors and surgeons, it has received a modest rating of 2 stars based on 5 reviews. Notably, the facility does not accept credit cards. Although it is listed as open, the business hours are unspecified, indicating it may operate on an appointment-only basis.', 'distance': 0.0}
# {'_id': ObjectId('671b444cefc3fbf09a7da6d3'), 'business_id': 'zITiOKyBNxWrhrj67SBqEQ', 'name': 'Susanne Ramos, MD', 'address': '2323 Oak Park Ln, Ste 101', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4287212, 'longitude': -119.7250697, 'stars': 4, 'review_count': 25, 'is_open': 1, 'attributes': {'ByAppointmentOnly': 'True', 'BusinessAcceptsCreditCards': 'True'}, 'categories': 'Doctors, Health & Medical, Obstetricians & Gynecologists', 'hours': {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', 'Wednesday': '9:0-17:0', 'Thursday': '9:0-17:0', 'Friday': '9:0-17:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7250697, 34.4287212]}, 'description': "Susanne Ramos, MD, is a highly-rated medical practice located at 2323 Oak Park Ln, Ste 101 in Santa Barbara, CA, 93105. Specializing in obstetrics and gynecology, Dr. Ramos's practice is dedicated to providing comprehensive health and medical care for women. With a solid 4-star rating based on 25 reviews, patients appreciate the quality of care they receive. The practice operates Monday through Friday from 9:00 AM to 5:00 PM and accepts appointments only, ensuring personalized and timely service. Additionally, the practice accepts credit cards, offering convenience for its clients.", 'distance': 2.219580670251001}

# %% [markdown]
# b. Vector Search with DiskANN

# %%
# First pipeline: Vector search

# create index
command = {
    "createIndexes": "business",
    "indexes": [
        {
            "key": {
                "embeddings": "cosmosSearch"
            },

            "name": "diskann_index",
            "cosmosSearchOptions": {
                "kind": "vector-diskann",
                "maxDegree": 32,
                "lBuild": 64,
                "similarity": "L2",
                "dimensions": 1536
            }
        }
    ]

}
db.command(command)
# Out:
# {'raw': {'defaultShard': {'numIndexesBefore': 5,
#    'numIndexesAfter': 5,
#    'createdCollectionAutomatically': False,
#    'note': 'all indexes already exist',
#    'ok': 1}},
#  'ok': 1}

# %%
# search query
vector_search_pipeline = [
    {
        '$search': {
            'cosmosSearch': {
                'path': 'embeddings',
                'vector': business_embed,
                'lSearch': 64,
                'k': 5  # Limit to top 5 closest vectors
            }
        }
    }
]
# Execute the aggregation
results = collection.aggregate(vector_search_pipeline)
# Print the results
for doc in results:
    doc.pop("embeddings")
    print(doc)
# Out:
# {'_id': ObjectId('671b4443efc3fbf09a7d46ce'), 'business_id': 'gfjjUlMC05kry6qjYyKrcA', 'name': 'West Coast Vascular', 'address': '2323 Oak Park Ln, Ste 201', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4287211, 'longitude': -119.7250939, 'stars': 2, 'review_count': 5, 'is_open': 1, 'attributes': {'BusinessAcceptsCreditCards': 'False'}, 'categories': 'Health & Medical, Doctors, Vascular Medicine, Medical Centers, Surgeons', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'Wednesday': '0:0-0:0', 'Thursday': '0:0-0:0', 'Friday': '0:0-0:0', 'Saturday': '0:0-0:0', 'Sunday': '0:0-0:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7250939, 34.4287211]}, 'description': 'West Coast Vascular, located at 2323 Oak Park Ln, Ste 201, Santa Barbara, CA 93105, is a specialized medical center focusing on vascular medicine and surgery. Despite its convenient location and comprehensive services in the health and medical sectors, including doctors and surgeons, it has received a modest rating of 2 stars based on 5 reviews. Notably, the facility does not accept credit cards. Although it is listed as open, the business hours are unspecified, indicating it may operate on an appointment-only basis.'}
# {'_id': ObjectId('671b443befc3fbf09a7cff3a'), 'business_id': 'HMTnTZmg--meLwCeqAyADw', 'name': 'Center For Womens Health Care', 'address': '2329 Oak Park Ln', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4289492, 'longitude': -119.7254785, 'stars': 2.5, 'review_count': 6, 'is_open': 1, 'attributes': None, 'categories': 'Health & Medical, Obstetricians & Gynecologists, Doctors', 'hours': None, 'location': {'type': 'Point', 'coordinates': [-119.7254785, 34.4289492]}, 'description': "The Center For Women's Health Care, located at 2329 Oak Park Ln in Santa Barbara, CA, specializes in health and medical services with a focus on obstetricians and gynecologists. With an overall rating of 2.5 stars based on six reviews, this clinic strives to provide essential healthcare services to women in the community. Despite mixed reviews, the Center remains open and operational, dedicated to offering medical expertise and care in a conveniently accessible location."}
# {'_id': ObjectId('671b4444efc3fbf09a7d4e31'), 'business_id': 'ism2oW6IxtrhToHtUVmv5g', 'name': 'Coast To Coast Cardiology', 'address': '836 Anacapa St, No. 150', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93102', 'latitude': 34.4217314, 'longitude': -119.6987907, 'stars': 3, 'review_count': 5, 'is_open': 1, 'attributes': None, 'categories': 'Pets, Veterinarians', 'hours': None, 'location': {'type': 'Point', 'coordinates': [-119.6987907, 34.4217314]}, 'description': 'Coast To Coast Cardiology, located at 836 Anacapa St, No. 150, Santa Barbara, CA 93102, is a veterinary clinic specializing in cardiology services for pets. Despite its name, the clinic has garnered an average rating of 3 stars from 5 reviews, indicating a mixed reception among clients. The clinic remains open and operational, providing essential heart-related care for pets in the Santa Barbara area.'}
# {'_id': ObjectId('671b443befc3fbf09a7cfe7f'), 'business_id': '-QUKuwoGTJRg-mOfHpM1hA', 'name': 'Santa Barbara Center for Oral & Maxillofacial Surgery', 'address': '9 E Pedregosa', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93101', 'latitude': 34.4303885284, 'longitude': -119.7133097749, 'stars': 5, 'review_count': 31, 'is_open': 1, 'attributes': {'ByAppointmentOnly': 'True', 'AcceptsInsurance': 'True', 'BusinessAcceptsCreditCards': 'True'}, 'categories': 'Surgeons, Cosmetic Dentists, Health & Medical, Dentists, Doctors, Oral Surgeons', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', 'Wednesday': '8:0-17:0', 'Thursday': '8:0-17:0', 'Friday': '8:0-17:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7133097749, 34.4303885284]}, 'description': 'The Santa Barbara Center for Oral & Maxillofacial Surgery, located at 9 E Pedregosa, Santa Barbara, CA 93101, is a highly-rated medical practice specializing in a range of oral and maxillofacial surgical services. With a perfect 5-star rating based on 31 reviews, the center is well-regarded for its expertise in surgeons, cosmetic dentists, and oral surgeons. The practice operates by appointment only and accepts insurance and credit cards for convenience. Open Tuesday through Friday from 8:00 AM to 5:00 PM, the center is dedicated to providing top-notch care in the fields of health and medical services.'}
# {'_id': ObjectId('671b4458efc3fbf09a7e184e'), 'business_id': 'dvQQSwBI1OlMsI0x-_yGZA', 'name': 'Santa Barbara Surgical Center', 'address': '3045 De La Vina St', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4396906, 'longitude': -119.7296389, 'stars': 4.5, 'review_count': 9, 'is_open': 1, 'attributes': None, 'categories': 'Health & Medical, Medical Centers', 'hours': None, 'location': {'type': 'Point', 'coordinates': [-119.7296389, 34.4396906]}, 'description': 'Santa Barbara Surgical Center, located at 3045 De La Vina St in Santa Barbara, CA, is a highly-rated medical facility specializing in health and medical services, particularly in surgical procedures. With a commendable rating of 4.5 stars based on 9 reviews, this medical center is committed to providing exceptional care and advanced surgical treatments. The center is operational and serves as a trusted healthcare provider in the community, conveniently situated with a latitude of 34.4396906 and a longitude of -119.7296389.'}

# %% [markdown]
# c. Vector Search with filter

# %%
# create index on filter related fields
command = { "createIndexes": "business", "indexes": [ { "key": { "is_open": 1 }, "name": "is_open" } ] }
db.command(command)

pipeline = [

                {
                    "$search": {
                        "cosmosSearch": {
                            "path": "embeddings",
                            "vector": business_embed,  # Replace with your actual vector
                            "k": 5,  # Limit to top 5 closest vectors
                            "filter": {"$and": [{ "is_open": { "$eq": 1 } }
                                                ]}
                        }
                    }
                },
                {
                    "$limit": 5  # Limit to top 5 results
                }
            ]

# Execute the aggregation
results = collection.aggregate(pipeline)

# Print the results
for doc in results:
    doc.pop("embeddings")
    print(doc)
# Out:
# {'_id': ObjectId('671b4443efc3fbf09a7d46ce'), 'business_id': 'gfjjUlMC05kry6qjYyKrcA', 'name': 'West Coast Vascular', 'address': '2323 Oak Park Ln, Ste 201', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4287211, 'longitude': -119.7250939, 'stars': 2, 'review_count': 5, 'is_open': 1, 'attributes': {'BusinessAcceptsCreditCards': 'False'}, 'categories': 'Health & Medical, Doctors, Vascular Medicine, Medical Centers, Surgeons', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'Wednesday': '0:0-0:0', 'Thursday': '0:0-0:0', 'Friday': '0:0-0:0', 'Saturday': '0:0-0:0', 'Sunday': '0:0-0:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7250939, 34.4287211]}, 'description': 'West Coast Vascular, located at 2323 Oak Park Ln, Ste 201, Santa Barbara, CA 93105, is a specialized medical center focusing on vascular medicine and surgery. Despite its convenient location and comprehensive services in the health and medical sectors, including doctors and surgeons, it has received a modest rating of 2 stars based on 5 reviews. Notably, the facility does not accept credit cards. Although it is listed as open, the business hours are unspecified, indicating it may operate on an appointment-only basis.', '__cosmos_meta__': {'score': 0.0}}
# {'_id': ObjectId('671b443befc3fbf09a7cff3a'), 'business_id': 'HMTnTZmg--meLwCeqAyADw', 'name': 'Center For Womens Health Care', 'address': '2329 Oak Park Ln', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4289492, 'longitude': -119.7254785, 'stars': 2.5, 'review_count': 6, 'is_open': 1, 'attributes': None, 'categories': 'Health & Medical, Obstetricians & Gynecologists, Doctors', 'hours': None, 'location': {'type': 'Point', 'coordinates': [-119.7254785, 34.4289492]}, 'description': "The Center For Women's Health Care, located at 2329 Oak Park Ln in Santa Barbara, CA, specializes in health and medical services with a focus on obstetricians and gynecologists. With an overall rating of 2.5 stars based on six reviews, this clinic strives to provide essential healthcare services to women in the community. Despite mixed reviews, the Center remains open and operational, dedicated to offering medical expertise and care in a conveniently accessible location.", '__cosmos_meta__': {'score': 0.44573442648416867}}
# {'_id': ObjectId('671b4444efc3fbf09a7d4e31'), 'business_id': 'ism2oW6IxtrhToHtUVmv5g', 'name': 'Coast To Coast Cardiology', 'address': '836 Anacapa St, No. 150', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93102', 'latitude': 34.4217314, 'longitude': -119.6987907, 'stars': 3, 'review_count': 5, 'is_open': 1, 'attributes': None, 'categories': 'Pets, Veterinarians', 'hours': None, 'location': {'type': 'Point', 'coordinates': [-119.6987907, 34.4217314]}, 'description': 'Coast To Coast Cardiology, located at 836 Anacapa St, No. 150, Santa Barbara, CA 93102, is a veterinary clinic specializing in cardiology services for pets. Despite its name, the clinic has garnered an average rating of 3 stars from 5 reviews, indicating a mixed reception among clients. The clinic remains open and operational, providing essential heart-related care for pets in the Santa Barbara area.', '__cosmos_meta__': {'score': 0.4711971934857523}}
# {'_id': ObjectId('671b443befc3fbf09a7cfe7f'), 'business_id': '-QUKuwoGTJRg-mOfHpM1hA', 'name': 'Santa Barbara Center for Oral & Maxillofacial Surgery', 'address': '9 E Pedregosa', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93101', 'latitude': 34.4303885284, 'longitude': -119.7133097749, 'stars': 5, 'review_count': 31, 'is_open': 1, 'attributes': {'ByAppointmentOnly': 'True', 'AcceptsInsurance': 'True', 'BusinessAcceptsCreditCards': 'True'}, 'categories': 'Surgeons, Cosmetic Dentists, Health & Medical, Dentists, Doctors, Oral Surgeons', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', 'Wednesday': '8:0-17:0', 'Thursday': '8:0-17:0', 'Friday': '8:0-17:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7133097749, 34.4303885284]}, 'description': 'The Santa Barbara Center for Oral & Maxillofacial Surgery, located at 9 E Pedregosa, Santa Barbara, CA 93101, is a highly-rated medical practice specializing in a range of oral and maxillofacial surgical services. With a perfect 5-star rating based on 31 reviews, the center is well-regarded for its expertise in surgeons, cosmetic dentists, and oral surgeons. The practice operates by appointment only and accepts insurance and credit cards for convenience. Open Tuesday through Friday from 8:00 AM to 5:00 PM, the center is dedicated to providing top-notch care in the fields of health and medical services.', '__cosmos_meta__': {'score': 0.48169412431805947}}
# {'_id': ObjectId('671b4458efc3fbf09a7e184e'), 'business_id': 'dvQQSwBI1OlMsI0x-_yGZA', 'name': 'Santa Barbara Surgical Center', 'address': '3045 De La Vina St', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4396906, 'longitude': -119.7296389, 'stars': 4.5, 'review_count': 9, 'is_open': 1, 'attributes': None, 'categories': 'Health & Medical, Medical Centers', 'hours': None, 'location': {'type': 'Point', 'coordinates': [-119.7296389, 34.4396906]}, 'description': 'Santa Barbara Surgical Center, located at 3045 De La Vina St in Santa Barbara, CA, is a highly-rated medical facility specializing in health and medical services, particularly in surgical procedures. With a commendable rating of 4.5 stars based on 9 reviews, this medical center is committed to providing exceptional care and advanced surgical treatments. The center is operational and serves as a trusted healthcare provider in the community, conveniently situated with a latitude of 34.4396906 and a longitude of -119.7296389.', '__cosmos_meta__': {'score': 0.48698506547207754}}

# %% [markdown]
# d. Combine Search Query with Geo Location

# %%
# Create an index on the location field
command = { "createIndexes": "business", "indexes": [ { "key": { "location": 1 }, "name": "location" } ] }
db.command(command)
# Search for the top 5 closest vectors to the query "Locksmith" within a 1 mile radius of longitude 119 W and latitude 34 N
pipeline = [

                {
                    "$search": {
                        "cosmosSearch": {
                            "path": "embeddings",
                            "query": "Locksmith",  # Replace with your query
                            "k": 5,  # Limit to top 5 closest vectors
                            "filter": {"$and": [
                                { "is_open": { "$eq": 1 } },
                                # all documents within a 1 mile radius of longitude 119 W and latitude 34 N.
                                #  The query converts the distance to radians by dividing by the approximate equatorial radius of the earth, 3963.2 miles
                                {"location": {"$geoWithin": {"$centerSphere":[[-119.7192861804, 34.4102485028], 1/3963.2 ]}}}
                                                ]}
                        }
                    }
                },
                {
                    "$limit": 5  # Limit to top 5 results
                }
            ]

# Execute the aggregation
results = collection.aggregate(pipeline)
restults = [results]
# Print the results
for doc in results:
    doc.pop("embeddings")
    print(doc)
# Out:
# {'_id': ObjectId('671b443defc3fbf09a7d0b96'), 'business_id': 'xI-srUR-M8jYQEm-3cVOdA', 'name': 'Master Locksmith - Santa Barbara', 'address': '', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93101', 'latitude': 34.420334, 'longitude': -119.7107494, 'stars': 4.5, 'review_count': 16, 'is_open': 1, 'attributes': {'ByAppointmentOnly': 'False', 'BusinessAcceptsCreditCards': 'True'}, 'categories': 'Garage Door Services, Keys & Locksmiths, Home Services', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'Wednesday': '0:0-0:0', 'Thursday': '0:0-0:0', 'Friday': '0:0-0:0', 'Saturday': '0:0-0:0', 'Sunday': '0:0-0:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7107494, 34.420334]}, 'description': '### Business Summary\n\nMaster Locksmith - Santa Barbara, located in the heart of Santa Barbara, CA, is a highly-rated locksmith service specializing in garage door services, key duplication, and various home services. With a commendable rating of 4.5 stars based on 16 reviews, the business is known for its reliability and excellent customer service. Open and operating throughout the week, Master Locksmith offers the convenience of accepting credit card payments and provides services without requiring prior appointments. Whether you need emergency lockout assistance or routine locksmith services, Master Locksmith - Santa Barbara is a trusted and accessible option in the area.', '__cosmos_meta__': {'score': 0.569849662572271}}
# {'_id': ObjectId('671b4440efc3fbf09a7d2aff'), 'business_id': 'TuTtiyKcTqT9d0LWg3BtLg', 'name': 'HandyMan Dmytro', 'address': '1260 Mountain View Rd', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93109', 'latitude': 34.4102485028, 'longitude': -119.7192861804, 'stars': 5, 'review_count': 7, 'is_open': 1, 'attributes': {'ByAppointmentOnly': 'True', 'BusinessAcceptsCreditCards': 'True', 'BusinessAcceptsBitcoin': 'True'}, 'categories': 'Home Services, Handyman', 'hours': {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', 'Wednesday': '8:0-17:0', 'Thursday': '8:0-17:0', 'Friday': '8:0-17:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7192861804, 34.4102485028]}, 'description': 'HandyMan Dmytro, located at 1260 Mountain View Rd in Santa Barbara, CA, is a top-rated home services provider specializing in handyman tasks. This business boasts a perfect 5-star rating based on 7 reviews, reflecting its commitment to quality and customer satisfaction. Open five days a week from 8:00 AM to 5:00 PM, HandyMan Dmytro operates by appointment only and offers convenient payment options, accepting both credit cards and Bitcoin. Whether you need minor repairs or more extensive home improvements, HandyMan Dmytro is a reliable choice for residents in the Santa Barbara area.', '__cosmos_meta__': {'score': 0.665902763044288}}
# {'_id': ObjectId('671b4466efc3fbf09a7e9ac6'), 'business_id': 'rZQqiElaeM7JO2rQAXHK2w', 'name': 'Jerry The Plumber', 'address': '1521 San Miguel Ave', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93109', 'latitude': 34.3991953, 'longitude': -119.715433, 'stars': 4.5, 'review_count': 9, 'is_open': 1, 'attributes': {'BusinessAcceptsCreditCards': 'True'}, 'categories': 'Plumbing, Hydro-jetting, Water Heater Installation/Repair, Home Services, Local Services', 'hours': {'Monday': '8:0-16:30', 'Tuesday': '8:0-16:30', 'Wednesday': '8:0-16:30', 'Thursday': '8:0-16:30', 'Friday': '8:0-16:30'}, 'location': {'type': 'Point', 'coordinates': [-119.715433, 34.3991953]}, 'description': 'Jerry The Plumber, located at 1521 San Miguel Ave, Santa Barbara, CA 93109, is a highly-rated plumbing service provider with a 4.5-star rating based on 9 reviews. Specializing in a range of services including plumbing, hydro-jetting, water heater installation and repair, Jerry The Plumber caters to both home services and local services needs. The business operates from Monday to Friday, from 8:00 AM to 4:30 PM, and accepts credit card payments for customer convenience. With a commitment to quality and reliability, Jerry The Plumber is a trusted choice for residents in the Santa Barbara area.', '__cosmos_meta__': {'score': 0.6864732531333293}}
# {'_id': ObjectId('671b4454efc3fbf09a7df0c9'), 'business_id': 'h0Gx3tVxv2ps_cCYiT2USw', 'name': 'Shower Glass Pro', 'address': '', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93101', 'latitude': 34.420334, 'longitude': -119.7107494, 'stars': 4.5, 'review_count': 15, 'is_open': 1, 'attributes': {'ByAppointmentOnly': 'True', 'Smoking': 'None', 'BikeParking': 'True', 'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", 'WheelchairAccessible': 'False', 'WiFi': 'None', 'BusinessAcceptsBitcoin': 'False', 'DogsAllowed': 'True', 'BusinessAcceptsCreditCards': 'True'}, 'categories': 'Home & Garden, Kitchen & Bath, Shopping, Home Services, Door Sales/Installation, Contractors, Windows Installation, Glass & Mirrors', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '7:0-16:30', 'Wednesday': '7:0-16:30', 'Thursday': '7:0-16:30', 'Friday': '7:0-16:30', 'Saturday': '7:0-16:30'}, 'location': {'type': 'Point', 'coordinates': [-119.7107494, 34.420334]}, 'description': 'Shower Glass Pro, located in Santa Barbara, CA, is a highly-rated business specializing in the installation and sales of shower glass, doors, windows, and mirrors. With an impressive 4.5-star rating based on 15 reviews, this business is known for its quality service in the Home & Garden, Kitchen & Bath, and Home Services categories. Operating by appointment only, Shower Glass Pro offers convenient bike parking and allows dogs on the premises, although it is not wheelchair accessible. The business accepts credit cards but does not accommodate Bitcoin transactions. Shower Glass Pro is open from Tuesday to Saturday, 7:00 AM to 4:30 PM, providing exceptional service to enhance the beauty and functionality of your home.', '__cosmos_meta__': {'score': 0.6874163099849037}}
# {'_id': ObjectId('671b4464efc3fbf09a7e88bd'), 'business_id': 'Kvzyns3-j46A518BRiOxeA', 'name': 'Tony Toro Construction', 'address': '2016 Red Rose Way, Ste 9', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4033612, 'longitude': -119.7238315, 'stars': 4.5, 'review_count': 7, 'is_open': 1, 'attributes': {'BusinessAcceptsCreditCards': 'False', 'BusinessAcceptsBitcoin': 'False'}, 'categories': 'Handyman, Flooring, Plumbing, Contractors, Drywall Installation & Repair, Real Estate Agents, Kitchen & Bath, Electricians, Real Estate, Shopping, Home Services, Home & Garden', 'hours': {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', 'Wednesday': '9:0-17:0', 'Thursday': '9:0-17:0', 'Friday': '9:0-17:0', 'Saturday': '9:0-17:0', 'Sunday': '9:0-17:0'}, 'location': {'type': 'Point', 'coordinates': [-119.7238315, 34.4033612]}, 'description': 'Tony Toro Construction is a well-regarded construction company based in Santa Barbara, California, located at 2016 Red Rose Way, Ste 9. Specializing in a comprehensive range of services including handyman work, flooring, plumbing, drywall installation and repair, kitchen and bath remodeling, and electrical services, this versatile firm also offers real estate agent services. Operating with a commendable 4.5-star rating from seven reviews, Tony Toro Construction prides itself on delivering quality home and garden services. Open daily from 9 AM to 5 PM, the business is dedicated to meeting the needs of its customers, although it does not currently accept credit cards or Bitcoin as payment methods.', '__cosmos_meta__': {'score': 0.6904807280973123}}

# %%
# Alternative: Search Query with GeoNear Operator
pipeline = [
    {
        "$geoNear": {
            "key": "location",
            "near": user_location,
            "distanceField": "distance",  # Field to store the calculated distance
            "maxDistance": 5,  # Maximum distance in meters (5 km)
            "spherical": True,  # Use spherical geometry
            "$match": {
                "isOpen": True,  # Filter for open restaurants
                "stars": {"$gte": 2}  # Filter by rating >= 2
            },
            # "$limit": 5  # Limit to top 5 results
        }
    },
    {
        "$unionWith": {
            "coll": "business",  # Specify the collection to union with
            "pipeline": [
                {
                    "$search": {
                        "cosmosSearch": {
                            "path": "embeddings",
                            "query": "Locksmith",  # Replace with your actual vector
                            "k": 5  # Limit to top 5 closest vectors
                        }
                    }
                },
                {
                    "$limit": 5  # Limit to top 5 results
                }
            ]
        }
    }
]

# Execute the aggregation
results = collection.aggregate(pipeline)

# Print the results
for doc in results:
    print(doc)
# Out:
# {'_id': ObjectId('671b4443efc3fbf09a7d46ce'), 'business_id': 'gfjjUlMC05kry6qjYyKrcA', 'name': 'West Coast Vascular', 'address': '2323 Oak Park Ln, Ste 201', 'city': 'Santa Barbara', 'state': 'CA', 'postal_code': '93105', 'latitude': 34.4287211, 'longitude': -119.7250939, 'stars': 2, 'review_count': 5, 'is_open': 1, 'attributes': {'BusinessAcceptsCreditCards': 'False'}, 'categories': 'Health & Medical, Doctors, Vascular Medicine, Medical Centers, Surgeons', 'hours': {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'Wednesday': '0:0-0:0', 'Thursday': '0:0-0:0', 'Friday': '0:0-0:0', 'Saturday': '0:0-0:0', 'Sunday': '0:0-0:0'}, 'location': {'type': 'Point', 'coordinates': [-119.